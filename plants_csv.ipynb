# %% [markdown]
# <a href="https://colab.research.google.com/github/Davie256/Home-work/blob/main/plants_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
csv_content = '''name, score, location
maize_01, 0.87, field_A
maize_02, 0.43, field_B
maize_03, 0.71, field_A
maize_04, 0.19, field_C
maize_05, 0.95, filed_B'''

with open('plants.csv', 'w') as f:
  f.write(csv_content)

print('plants.csv created!')
# Out:
# plants.csv created!

# %%
import csv

with open('plants.csv', 'r') as f:
  reader = csv.DictReader(f)

  for row in reader:
    name = row['name']
    score = float(row['score'])
    result = classify_health(score)
    print(f'{name}: {result}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_4793/1174391319.py in <cell line: 0>()
#       6   for row in reader:
#       7     name = row['name']
# ----> 8     score = float(row['score'])
#       9     result = classify_health(score)
#      10     print(f'{name}: {result}')
#
# KeyError: 'score'
